# %% [markdown]
# ### [데이터타입 조회]
# ### kopo_customerdata.csv 파일을 불러온 후
# ### kopo_customerData 변수에 담으세요 이후
# ### STATENAME, GENDER 컬럼 첫 5개행 조회하세요

# %%
import pandas as pd
# kopo_customerData변수에 kopo_customerdata를 대입
kopo_customerData = pd.read_csv("../dataset/kopo_customerdata.csv")
# 타겟 컬럼 설정
targetColumns = ["STATENAME", "GENDER"]
genderNameIdx = kopo_customerData.columns.get_loc("GENDER")
stateNameIdx = kopo_customerData.columns.get_loc("STATENAME")
# kopo_customerData의 타겟컬럼의 모든행을 조회해서 상위 5개만 노출
kopo_customerData.loc[0:4, targetColumns]
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male

# %%
kopo_customerData
# Out:
#         CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2    Male    0        1      1         0
# 1            1190338    State2   2    Male    0        1      0         1
# 2            1424715    State2   2  Female    0        2      0         0
# 3            2483305    State2   2    Male    0        1      0         1
# 4            1178802    State2   2    Male    0        1      0         1
# ...              ...       ...  ..     ...  ...      ...    ...       ...
# 299995        465757    State1   1    Male    0        1      0         0
# 299996       1890264    State1   1    Male    0        1      0         1
# 299997       1857537    State1   1  Female    0        2      0         0
# 299998       2209324    State1   1    Male    0        1      0         1
# 299999       1875146    State1   1    Male    0        1      0         1
#
#         TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  \
# ...
